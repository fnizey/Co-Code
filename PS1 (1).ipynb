# %% [markdown]
# # How to add code into terminal, and load!:

# %%
# In terminal write - to publish changes:
git add .
git commit -m "I changed xyz"
git push

# Loading into code - given other guys changes
git pull

# %% [markdown]
# # Problem Set 1

# %% [markdown]
# I. Variables and types
#
# II. Conditional execution and loops
#
# III. Iteration and convergence

# %% [markdown]
# ## I. Variables and types

# %% [markdown]
# ### Exercise 1
#
# Compute the following mathematical expressions:
#
# $$\frac{2.4+5.6}{2}$$
#
# $$\log(1+e^{-x^2})$$
#
#
# $$2\times\left(1+\frac{5}{100}\right)^{3}$$
#
# $$\sqrt{(2^{2}+3^{2} )}$$

# %%
x = 1
import math
#Q1 - How to do it?
print((2.4 + 5.6) / 2)

#Q2
print(math.log(1 + math.exp(-x**2)))

#Q3
print(2 * (1 + 5/100)**3)

#Q4
print((2**2 + 3**2)**0.5)

# %% [markdown]
# ### Exercise 2
# Assign your full name to a variable. Now write code that returns your initials from that variable. That is, if your name is Ada Lovelace, your code should return A.L.

# %%
name = 'Joakim Kroken Aarseth'
initials = name[0]+'.'+name[7]+'.'+name[14]+'.'

print(initials)

# Or do this:
name1 = 'Anton August Molle'
[first, middle, last] = name1.split()
print(first[0] + '.' + middle[0] + '.' + last[0] + '.')

# %% [markdown]
# ### Exercise 3
# Define a variable
#     `volume = 10.345`
# and apply string formatting methods to print the following:
#
#     The total volume is 10.345.
#
#
# Now limit the number of decimals to two as follows:
#
#     The total volume is 10.35.

# %% [markdown]
# NB! There are currently two ways of doing this in Python 3. However, one of these will be deprecated in the next version of Python and is only included in Python 3 to ensure backwards compatibility. Thus, you should focus on mastering the syntax described here:
# https://www.w3schools.com/python/ref_string_format.asp

# %%
volume = 10.345

#Q1
print('The total volume is: %0.3f' % volume)
print('The total volume is:', volume)
print('The total volume is: {}'.format(volume))

#Q2
print(f"The total volume is: {volume:.2f}")
print('The total volume is: {:.2f}'.format(volume))

# %% [markdown]
# ### Exercise 4
# Generate a list of numbers [0,1,2,3,4] using the range function. Then, do the following:
#
# i) Add an extra number 3 at the end of the list.
#
# ii) Sort the list
#
# iii) Remove the 4th element of the list
#
# iv) Insert a string in the list as the 2nd element

# %%
numbers = []

#List
for i in range(5):
    numbers.append(i)
print(numbers)

#Q1
numbers.append(3)
print(numbers)

#Q2
numbers.sort()
print(numbers)

#Q3
del numbers[3]
print(numbers)

#Q4
numbers.insert(1, "String")
print(numbers)

# %% [markdown]
# ### Exercise 5
#
# Given the following tuple `t = (8,9,10,7,8,4,3,3,8,2,9,8)`.
#
# Do the following:
#
# i) Count the number of occurences of the number 8 in `t`.
#
# ii) Print the length of `t`.
#
# iii) Covert `t` into a list type object.

# %%
t = (8,9,10,7,8,4,3,3,8,2,9,8)

#Q1
print(t.count(8))

#Q2
print(len(t))

#Q3
print(list(t))

# %% [markdown]
# ### Exercise 6
# Consider the following dictionary:
#
#     commodity = {
#         'oil' : 501,
#         'copper' : ['upper grade', 'lower grade'],
#         'soybean' : ['asia','south america', 'north america']
#     }
#
# Do the following:
#
# i) Add a key to commodity called 'natural gas'.
#
# ii) Set the value of 'natural gas' to be a list consisting of the strings 'H1', 'H2', and 'H3'.
#
# iii) Sort the values in the list stored under the 'soybean' key.
#
# iv) Then remove 'upper grade' from the list stored under the 'copper' key.
#
# v) Add 50 to the value stored under the 'oil' key.

# %%
commodity = {
        'oil' : 501,
        'copper' : ['upper grade', 'lower grade'],
        'soybean' : ['asia','south america', 'north america']
    }

#Q1 and Q2
commodity['natural gas'] = ['H1', 'H2', 'H3']

#Q3
commodity['soybean'].sort()

#Q4
commodity['copper'].remove('upper grade')

#Q5
commodity['oil'] += 50

for key in commodity:
    print(key, ':', commodity[key])

# %% [markdown]
# ### Exercise 7
#
# ##### Create a new dictionary called price.
#
# Assign these key-value pairs to the dictionary:
#
#     "oil": 4
#     "copper": 2
#     "soybean": 1.5
#     "rice": 3
#
# ##### Now create another dictionary named stock. Assign the following key-value pairs to this dictionary:
#
#     "oil": 6
#     "copper": 0
#     "soybean": 32
#     "rice": 15
#
# Loop through each key in prices. For each key, print out the key along with its price and stock information. Example:
#
#     copper
#     price: 2
#     stock: 0
#
# ##### Finally, determine the revenue if you sold all of the commodities at the current prices.
# Your code should return the revenue from each commodity sold and finally the total revenue.

# %%
price = {'oil' : 4,
        'copper' : 2,
        'soybean' : 1.5,
        'rice' : 3
}

stock = {'oil' : 6,
        'copper' : 0,
        'soybean' : 32,
        'rice' : 15
}

total = 0

for k in price:
    print(k)
    print('Price ', price[k])
    print('Stock: ', stock[k])
    revenue = price[k] * stock[k]
    print(f"Revenue given sale is:", revenue)
    total += revenue
    print()
print(f"Total revenue is:", total)

# %% [markdown]
# ## II. Conditional execution and loops

# %% [markdown]
# ### Exercise 8
# Pick an integer $y$ between 0 and 5. Define a variable `sum_y=1`.
#
# Do the following
#
# i) if y is less than 3, add 1 to `sum_y` and print `sum_y`
#
# ii) if y >3 substract 1  from `sum_y` and print `sum_y`
#
# iii) if y=3 then print 'no change'

# %%
import random
y = random.randint(0,5)
print(f"Y is: ",  y)
sum_y = 1


if y < 3:
    sum_y = sum_y + 1
    print(f"Sum for Y is: ", sum_y)
elif y > 3:
    sum_y = sum_y - 1
    print(f"Sum for Y is: ", sum_y)
else:
    print('No change')

# %% [markdown]
# ### Exercise 9
# Create a list containing the squared integers between 0 and 10.

# %%
squares = []

for s in range(11):
    squares.append(s**2)
print(f"The squared integers from 0 to 10 are: {squares}")

# %% [markdown]
# ### Exercise 10
# List of all numbers between 1 and 50 that are divisible by 3.

# %%
#Method 1
div = []

for d in range(1,51):
    if d % 3 == 0:
        div.append(d)
print(div)

#Or do this:
div1 = [n for n in range(1,51) if n % 3 == 0]
print(div1)

# %% [markdown]
# ### Exercise 11
#
# Given the list `s = [0.9,-0.9,0.8,0.4,-0.1]`
#
# Write a comprehension that will extract the negative values of `s` and place them in a new list.

# %%
s = [0.9, -0.9, 0.8, 0.4, -0.1]
neg = []

for i in s:
    if i < 0:
        neg.append(i)
print(neg)

# or do this:

n = [x for x in s if x < 0]
print(n)

# %% [markdown]
# ### Exercise 12
#
# Generate a code that prints out all positive integers less than 7.

# %%
less = []

for b in range(7):
    less.append(b)
    print(b)

# %% [markdown]
# ### Exercise 13
# The number $\pi$ can be computed with Leibniz's formula
#
# $$ \pi = \frac{4}{1} - \frac{4}{3} + \frac{4}{5} - \frac{4}{7} + \frac{4}{9} - \frac{4}{11} + \dots $$
#
# that is, as the sum of the terms $(-1)^{k}\,\dfrac{4}{2k+1}$ for $k=0,1,2,\dots$
#
# Use a loop to accumulate the first $n$ terms of this sum and print the result for $n=100$ and for
# $n=1000$. How many correct decimals do you get in each case?

# %%
import math

for n in [100, 1000, 10000]:
    total = 0.0
    for k in range(n):
        total += ((-1)**k * 4) / (2*k + 1)
    print(f"Pi estimate with {n} terms: {total:.6f}")
    delta = math.pi-total
    print(f"Delta to real PI is: {delta:.2e}")
    print()

print(f"True PI is: {math.pi:.6f}")

# %% [markdown]
# ## III. Iteration and convergence
#
# The two exercises below are the first *numerical methods* of the course. Both take an equation,
# turn it into a rule of the form $x_{n+1}=g(x_n)$, and let a loop run that rule until it stops
# moving. Every technique in the second half of the course, Gauss–Jacobi, bisection, Newton,
# golden search, value function iteration, is this same loop with a different $g$.

# %% [markdown]
# ### Exercise 14. Iteration and convergence
#
# A firm's capital stock depreciates at a rate $\delta$ each year, and the firm invests a fixed
# amount $i$ each year. Capital therefore evolves according to
#
# $$k_{t+1} = (1-\delta)\,k_t + i, \qquad k_0 = 0, \quad \delta = 0.1, \quad i = 0.3 .$$
#
# A **steady state** (or **fixed point**) $k^{*}$ is a capital stock that reproduces itself,
#
# $$k^{*} = (1-\delta)k^{*} + i \qquad\Longleftrightarrow\qquad k^{*} = \frac{i}{\delta}.$$
#
# Subtracting this from the equation above gives the *deviation* from the steady state:
#
# $$k_{t+1} - k^{*} = (1-\delta)\,(k_t - k^{*})
# \qquad\Longrightarrow\qquad
# k_t - k^{*} = (1-\delta)^{t}\,(k_0 - k^{*}).$$
#
# So the distance to $k^{*}$ is multiplied by $(1-\delta)$ every single period, and the iteration
# converges, from **any** starting point, exactly when $|1-\delta| < 1$. That inequality is the
# whole idea behind every iterative method in this course.
#
# **i)** Use a `for` loop to compute $k_1,\dots,k_{20}$, printing one row per iteration with three
# columns: the iteration number, $k_t$ to six decimals, and the change $|k_{t+1}-k_t|$ in scientific
# notation. *(Use the string formatting you practised in Exercise 3.)*
#
# **ii)** Replace the `for` loop by a `while` loop that stops as soon as
# $|k_{t+1}-k_t| < 10^{-8}$. How many iterations does it take, and what value does it settle on?
#
# **iii)** Compute $k^{*}$ with the formula above and check that your loop found it.
#
# **iv)** Now set $\delta = 2.1$, so that the rule becomes $k_{t+1} = -1.1\,k_t + 0.3$. Run the loop
# again. What happens, and why? Add a `maxit` guard so that the loop can never run forever.

# %%
#Q1
k, delta, i = [0.0, 0.1, 0.3]


print(f" {'t':>4}  {'k':>12}  {'|Change|':>14}")
for t in range(20):
    k_new = (1 - delta) * k + i
    err   = abs(k_new - k)
    k     = k_new
    print(f"{t + 1:5d}   {k:12.6f}   {err:12.2e}")

# %%
#Q2
k, delta, i = [0.0, 0.1, 0.3]
tol = 1e-8
it = 0
err1 = 1

while err1 > tol:
    k_new = (1 - delta) * k + i
    err1   = abs(k_new - k)
    k     = k_ne
    it   += 1

print(f" converged in {it} interactions to k = {k:.10f}")
# Out:
#  converged in 165 interactions to k = 2.9999999154

# %%
#Q3
k_star = i / delta

print(f"analytic state state k* = {k_star:.10f}")
print(f"My loop stopped at k = {k:.10f}")
print(f"Distance of from truth = {abs(k_star - k):.2e}")
# Out:
# analytic state state k* = 3.0000000000
# My loop stopped at k = 2.9999999154
# Distance of from truth = 8.46e-08

# %%
#Q4
delta = 2.1
k = 0.0
i = 0.3
tol = 1e-8
it = 0
err1 = 1
maxit = 1000

print(f"{'it':>5} {'k':>12} {'|Change|':>20}")
while err1 > tol and it < maxit:
    k_new = -1.1 * k + i
    err1   = abs(k_new - k)
    k     = k_new
    it   += 1
    if it <= 10 or it % 100 == 0:
        print(f"{it:5d}     {k:14.3e}     {err1:12.2e}")

if err1 > tol:
    print(f"Converged in {it} interactions to k = {k:3e}")
# Out:
#    it            k             |Change|
#     1          3.000e-01         3.00e-01
#     2         -3.000e-02         3.30e-01
#     3          3.330e-01         3.63e-01
#     4         -6.630e-02         3.99e-01
#     5          3.729e-01         4.39e-01
#     6         -1.102e-01         4.83e-01
#     7          4.212e-01         5.31e-01
#     8         -1.634e-01         5.85e-01
#     9          4.797e-01         6.43e-01
#    10         -2.277e-01         7.07e-01
#   100         -1.969e+03         3.76e+03
#   200         -2.713e+07         5.18e+07
#   300         -3.739e+11         7.14e+11
#   400         -5.152e+15         9.84e+15
#   500         -7.100e+19         1.36e+20
#   600         -9.784e+23         1.87e+24
#   700         -1.348e+28         2.57e+28
#   800         -1.858e+32         3.55e+32
#   900         -2.560e+36         4.89e+36
#  1000         -3.528e+40         6.74e+40
# Converged in 1000 interactions to k = -3.528476e+40

# %% [markdown]
# ### Exercise 15. Fixed points and contraction
#
# The equation
#
# $$x^{2} = x + 2$$
#
# has the two solutions $x=2$ and $x=-1$. It can be rearranged into a fixed-point problem
# $x = g(x)$ in more than one way. Two natural choices are
#
# $$x_{n+1} = \sqrt{x_n + 2}
# \qquad\text{and}\qquad
# x_{n+1} = x_n^{2} - 2 .$$
#
# Both leave $x^{*}=2$ unchanged, so both have it as a fixed point. Whether an iteration of this kind
# actually *finds* it depends on the slope of the map at that point. If
#
# $$\bigl|g'(x^{*})\bigr| < 1$$
#
# then the distance to $x^{*}$ shrinks at every step, the map is a **contraction**, and close to
# the fixed point the errors satisfy
#
# $$\frac{\bigl|x_{n+1}-x^{*}\bigr|}{\bigl|x_{n}-x^{*}\bigr|} \;\longrightarrow\; \bigl|g'(x^{*})\bigr| .$$
#
# For the two rules above,
#
# $$g(x) = \sqrt{x+2}, \qquad g'(x) = \frac{1}{2\sqrt{x+2}}, \qquad g'(2) = \tfrac14,$$
#
# $$h(x) = x^{2}-2, \qquad h'(x) = 2x, \qquad h'(2) = 4 .$$
#
# (These two maps are inverses of one another, $h(g(x)) = x$, which is why their slopes at $x^{*}$
# are reciprocals. You met both of them, with pen and paper, in Question 4 of PS0.)
#
# *In Python, write the square root as* `(x + 2) ** 0.5`.
#
# **i)** Check that $x=2$ is a fixed point of both rules by evaluating `(2 + 2) ** 0.5` and
# `2 ** 2 - 2`.
#
# **ii)** Iterate the **first** rule from $x_0 = 1$ with a `while` loop, stopping when
# $|x_{n+1}-x_n| < 10^{-8}$. Print the iteration table. How many steps does it take? Compare your
# first four rows with the hand calculation in PS0 Question 4.
#
# **iii)** Add a fourth column to the table with the error ratio
# $|x_{n+1}-2| \, / \, |x_n - 2|$. What number does it settle on, and where does that number come
# from?
